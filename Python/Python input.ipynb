# %%
#input 사용 예시

name=input('이름이 어떻게 되시나요?')
print(name,'님 안녕하세요.')
# Out:
# 김도현 님 안녕하세요.

# %%
#input 사용 예시

num=int(input('몇분 이신가요?'))
if num>4:
    print('죄송하지만 자리가 부족해서 조금 기다리셔야 합니다.')
else:
    print('자리로 안내해 드리겠습니다.')
# Out:
# 자리로 안내해 드리겠습니다.
